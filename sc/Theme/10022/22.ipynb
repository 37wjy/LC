# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,9,1)
y = 0.6/(x)**0.5+0.4
plt.plot(x,y)

# %%
plt.plot(x,np.exp(x) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cb71b2b0e127> in <module>
# ----> 1 plt.plot(x,e^x)
#
# NameError: name 'e' is not defined
